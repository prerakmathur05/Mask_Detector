# %%
from IPython.display import clear_output

def display_board(board):
    print("  |   |  ")
    print(board[7]+" | "+board[8]+" | "+board[9])
    print("--|---|-- ")
    print(board[4]+" | "+board[5]+" | "+board[6])
    print("--|---|-- ")
    print(board[1]+" | "+board[2]+" | "+board[3])
    print("  |   |  ")
    
def player_input():
        marker=' '
        while marker!='X' and marker!='O':
              marker = input('Player 1, Enter O or X : ')
        mark1=marker
        mark2=' '
        if mark1 == 'X':
            mark2 ='O'
        else:
            mark2 = 'X'
        return (mark1,mark2)
def place_marker(board, marker, position):
        #display_board(board)
        #player_input()
        #board=[" "," "," "," "," "," "," "," "," "," "]
        #position = int(input('Enter the position for marker '))
        board[position] = marker
        return board
def win_check(board, mark):

    #horizontal
        if board[1] == board [2] == board[3] == mark:
            print(f' Player with marker {mark} has won ')
            u=1
        elif board[4] == board [5] == board[6] == mark:
            print(f' Player with marker {mark} has won ')
            u=1
        elif board[7] == board [8] == board[9] == mark:
            print(f' Player with marker {mark} has won ')
            u=1
    
    
    #vertival
        
        elif board[ 1] == board [4] == board[7] == mark :
            print(f' Player with marker {mark} has won ')
            u=1
        elif board[2] == board [5] == board[8] == mark :
            print(f' Player with marker {mark} has won ')
            u=1
        elif board[3] == board [6] == board[9] == mark:
            print(f' Player with marker {mark} has won ')
            u=1
        
       #diagonal 
        elif board[7] == board [5] == board[3] == mark :
            print(f' Player with marker {mark} has won ')
            u=1
        elif board[1] == board [5] == board[9] == mark :
            print(f' Player with marker {mark} has won ')
            u=1
        else:
            print("game is going ON")
            u=0
        return u

def space_check(board, position):
     return board[position]==" "
    
def full_board_check(board):
    for n in board:
        return n == " "
    
def player_choice(board):
    w=k
    while board[w]!=" ":
        print("Position already taken ")
        w = int(input(" Enter next position "))
    
    return w

print('Welcome to Tic Tac Toe!')
board = ['#',' ',' ',' ',' ',' ',' ',' ',' ',' ']

(mark1,mark2)=player_input()
#choose_first()
#place_marker(board, marker, position)
m=full_board_check(board)
#while True:
while m is not True:
    #myplayer1
    position1 = int(input('Player 1 Enter the position for marker '))
    #k=position1
    place_marker(board, mark1, position1)
    #player_choice(board)
    #board[player_choice(board)]= mark1
    display_board(board)
    z=win_check(board, mark1)
    if z== 1:
           break
    
    
    #myplayer 2
    position2 = int(input('Player 2 Enter the position for marker '))
    #k=position2
    place_marker(board, mark2, position2)
    #player_choice(board)
    #board[player_choice(board)]= mark2
    display_board(board)
    v=win_check(board, mark2)
    if v == 1:
             break

print("Game Ends")
# Out:
# Welcome to Tic Tac Toe!
# Player 1, Enter O or X : X
# Player 1 Enter the position for marker 4
#   |   |
#   |   |
# --|---|--
# X |   |
# --|---|--
#   |   |
#   |   |
# game is going ON
# Player 2 Enter the position for marker 5
#   |   |
#   |   |
# --|---|--
# X | O |
# --|---|--
#   |   |
#   |   |
# game is going ON
# Player 1 Enter the position for marker 1
#   |   |
#   |   |
# --|---|--
# X | O |
# --|---|--
# X |   |
#   |   |
# game is going ON
# Player 2 Enter the position for marker 6
#   |   |
#   |   |
# --|---|--
# X | O | O
# --|---|--
# X |   |
#   |   |
# game is going ON
# Player 1 Enter the position for marker 7
#   |   |
# X |   |
# --|---|--
# X | O | O
# --|---|--
# X |   |
#   |   |
#  Player with marker X has won
# Game Ends
